# %%
import pandas as pd
import seaborn as sns
import matplotlib.image as img
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Downloads/labels_my-project-name_2023-08-03-11-33-16.csv")

# %%
df.head()
# Out:
#   label_name  bbox_x  bbox_y  bbox_width  bbox_height     image_name  \
# 0     tiger1      58     187         182          313  ai4 image.jpg
# 1     tiger2     267     206         203          301  ai4 image.jpg
# 2     tiger3     512     231         503          524  ai4 image.jpg
# 3     tiger4    1044     216         336          503  ai4 image.jpg
#
#    image_width  image_height
# 0         1416           800
# 1         1416           800
# 2         1416           800
# 3         1416           800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   label_name    4 non-null      object
#  1   bbox_x        4 non-null      int64
#  2   bbox_y        4 non-null      int64
#  3   bbox_width    4 non-null      int64
#  4   bbox_height   4 non-null      int64
#  5   image_name    4 non-null      object
#  6   image_width   4 non-null      int64
#  7   image_height  4 non-null      int64
# dtypes: int64(6), object(2)
# memory usage: 384.0+ bytes

# %%
df.describe()
# Out:
#            bbox_x      bbox_y  bbox_width  bbox_height  image_width  \
# count     4.00000    4.000000    4.000000      4.00000          4.0
# mean    470.25000  210.000000  306.000000    410.25000       1416.0
# std     425.12459   18.457158  147.979728    119.63103          0.0
# min      58.00000  187.000000  182.000000    301.00000       1416.0
# 25%     214.75000  201.250000  197.750000    310.00000       1416.0
# 50%     389.50000  211.000000  269.500000    408.00000       1416.0
# 75%     645.00000  219.750000  377.750000    508.25000       1416.0
# max    1044.00000  231.000000  503.000000    524.00000       1416.0
#
#        image_height
# count           4.0
# mean          800.0
# std             0.0
# min           800.0
# 25%           800.0
# 50%           800.0
# 75%           800.0
# max           800.0

# %%
df.dropna()
# Out:
#   label_name  bbox_x  bbox_y  bbox_width  bbox_height     image_name  \
# 0     tiger1      58     187         182          313  ai4 image.jpg
# 1     tiger2     267     206         203          301  ai4 image.jpg
# 2     tiger3     512     231         503          524  ai4 image.jpg
# 3     tiger4    1044     216         336          503  ai4 image.jpg
#
#    image_width  image_height
# 0         1416           800
# 1         1416           800
# 2         1416           800
# 3         1416           800

# %%
sns.pairplot(df)

# %%
 sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(data=df)

# %%
sns.lmplot(data=df)

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(data=df)
# Out:
# <AxesSubplot:>

# %%
testingimg=img.imread("Downloads/ai4 image.jpg")
plt.imshow(testingimg)

# %%
import cv2

# %%
start_point=(50,50)
end_point=(10001,10009)
color=(255,0,0)
thickness=9

# %%
testingimg=cv2.rectangle(testingimg,start_point,end_point,color,thickness)
testingimg
# Out:
# array([[[111, 116,  96],
#         [111, 116,  96],
#         [111, 116,  96],
#         ...,
#         [ 66,  78,  58],
#         [ 66,  78,  58],
#         [ 66,  78,  58]],
#
#        [[109, 114,  94],
#         [110, 115,  95],
#         [109, 114,  94],
#         ...,
#         [ 66,  78,  58],
#         [ 66,  78,  58],
#         [ 66,  78,  58]],
#
#        [[106, 111,  91],
#         [107, 112,  92],
#         [107, 112,  92],
#         ...,
#         [ 67,  79,  59],
#         [ 67,  79,  59],
#         [ 67,  79,  59]],
#
#        ...,
#
#        [[140, 151, 145],
#         [140, 151, 145],
#         [139, 150, 144],
#         ...,
#         [ 83,  85,  72],
#         [ 83,  85,  72],
#         [ 82,  84,  71]],
#
#        [[140, 151, 145],
#         [140, 151, 145],
#         [139, 150, 144],
#         ...,
#         [ 83,  85,  72],
#         [ 83,  85,  72],
#         [ 83,  85,  72]],
#
#        [[140, 151, 145],
#         [140, 151, 145],
#         [139, 150, 144],
# ...

# %%
cv2.imshow("tiger",testingimg)
cv2.waitKey(0)
